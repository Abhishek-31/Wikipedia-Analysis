# %%
import re
import wikipedia
import wikipediaapi

# %%
with open("/home/abhishek/Documents/Wikipedia-Analysis/FAQ-Builder/City Data collector/final2.txt","r") as f:
    z=f.read().split('\n')
myset=set(z)
z=list(myset)
print(len(z))
print(z)
with open("final2.txt","w+") as f:
    for _ in z:
        f.write(_)
        f.write("\n")
print(z)
# Out:
# 7907
# ...

# %%
a={}
c=0
print("Files done")
wiki = wikipediaapi.Wikipedia('en')
for _ in z:
    print(">>")
    try:
        content=wikipedia.page(_).content
        try:
            k=content.find("== See also ==")
        except ValueError as e:
            print("solving *")
            try:
                k=content.find("== References ==")
            except:
                try:
                    k=content.find("== Further reading ==")
                except:
                    try:
                        k=content.find("== External links ==")
                    except:
                        pass
                    else:
                        content=content[0:k]
                else:
                    content=content[0:k]
                    
            else:
                content=content[0:k]
                
        else:
            content=content[0:k]
        
            
        if(c==0):
            f=open('%s.txt' % _,'w+')
            f.write(content)
            f.write("\n\n\n\n\n")
            f.write("tags\n")
            string=' '
            tags=re.findall(r'== (.*?) ==',content)
            
            if("References" in tags):
                tags.remove("References")
            if("External links" in tags):
                tags.remove("External links")
            if("See also" in tags):
                tags.remove("See also")
            if("Further reading" in tags):
                tags.remove("Further reading")
            l=string.join(tags)
            f.write(l)
        c=c+1
        a[_]={}
        a[_]["content"]=content
        tags=re.findall(r'== (.*?) ==',content)
        if("References" in tags):
            tags.remove("References")
        if("External links" in tags):
            tags.remove("External links")
        if("See also" in tags):
            tags.remove("See also")
        if("Further reading" in tags):
            tags.remove("Further reading")
        a[_]["headings"]= tags
        print(c)
        
    except Exception as exception:
        print("Inside an exception")
        print(type(exception))
        if(type(exception)==wikipedia.exceptions.DisambiguationError):
            print("Error coming for",end=" -> ")
            print(_)
            for check in exception.options:
                pg=wiki.page(check)
                if(pg.exists()):
                    c=c+1
                    print(c)
                    print(pg)
                    try:    
                        content=wikipedia.page(check).content
                        try:
                            x=content.find(".")
                        except:
                            print("rejected")
                        else:
                            l=content[0:x]
                            if("city" in l or "municipality" in l or "district" in l or "province" in l or "town" in l or "metropolis" in l):
                                print("accepted")
                                a[check]={}
                                try:
                                    k=content.find("== See also ==")
                                except:
                                    try:
                                        k=content.find("== References ==")
                                    except:
                                        try:
                                            k=content.find("== Further reading ==")
                                        except:
                                            try:
                                                k=content.find("== External links ==")
                                            except:
                                                pass
                                            else:
                                                content=content[0:k]
                                        else:
                                            content=content[0:k]
                    
                                    else:
                                        content=content[0:k]
                    
                                else:
                                    content=content[0:k]
                                a[check]["content"]=content
                                tags=re.findall(r'== (.*?) ==',content)
                                if("References" in tags):
                                    tags.remove("References")
                                if("External links" in tags):
                                    tags.remove("External links")
                                if("See also" in tags):
                                    tags.remove("See also")
                                if("Further reading" in tags):
                                    tags.remove("Further reading")
                                a[check]["headings"]=tags
                            else:
                                print("rejected")
                    except:`
                        pass
                else:
                    continue
        else:
            pass
# Out:
# Files done
# >>
# Inside an exception
# <class 'wikipedia.exceptions.WikipediaException'>
# >>
# 1
# >>
# 2
# >>
# Inside an exception
# <class 'wikipedia.exceptions.DisambiguationError'>
# Error coming for -> Norden
# 3
# Norden, Greater Manchester (id: 3722651, ns: 0)
# rejected
# 4
# Corfe Castle (village) (id: 159384, ns: 0)
# rejected
# 5
# Norden, Lower Saxony (id: 2288735, ns: 0)
# accepted
# 6
# Norden, California (id: 15594617, ns: 0)
# rejected
# 7
# Norden Township, Pennington County, Minnesota (id: 121243, ns: 0)
# accepted
# 8
# Norden, Nebraska (id: 43597935, ns: 0)
# rejected
# 9
# Hambach Forest (id: 53069847, ns: 0)
# rejected
# 10
# D/S Norden (id: 16398663, ns: 0)
# rejected
# 11
# Coop Norden (id: 5112334, ns: 0)
# rejected
# 12
# Norden (surname) (id: 39912055, ns: 0)
# rejected
# 13
# Norden Hartman (id: 18400467, ns: 0)
# rejected
# 14
# Norden Cricket Club (id: 451219, ns: 0)
# rejected
# 15
# Norden High School and Sports College (id: 33755830, ns: 0)
# ...

# %%
print(a)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
import json
with open("final_dictionary.txt","w+") as f:
    f.write(json.dumps(a))

count=0
for _ in a:
    count=count+1
print(count)

print(z.index("Bury"))

# %%
l=z[z.index("Bury"):]

with open("final2-2.txt","w+") as f:
    for _ in l:
        f.write(_)
        f.write("\n")

# %%
for _ in l:
    print(">>")
    try:
        content=wikipedia.page(_).content
        try:
            k=content.find("== See also ==")
        except ValueError as e:
            print("solving *")
            try:
                k=content.find("== References ==")
            except:
                try:
                    k=content.find("== Further reading ==")
                except:
                    try:
                        k=content.find("== External links ==")
                    except:
                        pass
                    else:
                        content=content[0:k]
                else:
                    content=content[0:k]
                    
            else:
                content=content[0:k]
                
        else:
            content=content[0:k]
        
            
        if(c==0):
            f=open('%s.txt' % _,'w+')
            f.write(content)
            f.write("\n\n\n\n\n")
            f.write("tags\n")
            string=' '
            tags=re.findall(r'== (.*?) ==',content)
            
            if("References" in tags):
                tags.remove("References")
            if("External links" in tags):
                tags.remove("External links")
            if("See also" in tags):
                tags.remove("See also")
            if("Further reading" in tags):
                tags.remove("Further reading")
            l=string.join(tags)
            f.write(l)
        c=c+1
        a[_]={}
        a[_]["content"]=content
        tags=re.findall(r'== (.*?) ==',content)
        if("References" in tags):
            tags.remove("References")
        if("External links" in tags):
            tags.remove("External links")
        if("See also" in tags):
            tags.remove("See also")
        if("Further reading" in tags):
            tags.remove("Further reading")
        a[_]["headings"]= tags
        print(c)
        
    except Exception as exception:
        print("Inside an exception")
        print(type(exception))
        if(type(exception)==wikipedia.exceptions.DisambiguationError):
            print("Error coming for",end=" -> ")
            print(_)
            for check in exception.options:
                pg=wiki.page(check)
                if(pg.exists()):
                    c=c+1
                    print(c)
                    print(pg)
                    try:    
                        content=wikipedia.page(check).content
                        try:
                            x=content.find(".")
                        except:
                            print("rejected")
                        else:
                            l=content[0:x]
                            if("city" in l or "municipality" in l or "district" in l or "province" in l or "town" in l or "metropolis" in l):
                                print("accepted")
                                a[check]={}
                                try:
                                    k=content.find("== See also ==")
                                except:
                                    try:
                                        k=content.find("== References ==")
                                    except:
                                        try:
                                            k=content.find("== Further reading ==")
                                        except:
                                            try:
                                                k=content.find("== External links ==")
                                            except:
                                                pass
                                            else:
                                                content=content[0:k]
                                        else:
                                            content=content[0:k]
                    
                                    else:
                                        content=content[0:k]
                    
                                else:
                                    content=content[0:k]
                                a[check]["content"]=content
                                tags=re.findall(r'== (.*?) ==',content)
                                if("References" in tags):
                                    tags.remove("References")
                                if("External links" in tags):
                                    tags.remove("External links")
                                if("See also" in tags):
                                    tags.remove("See also")
                                if("Further reading" in tags):
                                    tags.remove("Further reading")
                                a[check]["headings"]=tags
                            else:
                                print("rejected")
                    except:
                        pass
                else:
                    continue
        else:
            pass
# Out:
# >>
# Inside an exception
# <class 'wikipedia.exceptions.DisambiguationError'>
# Error coming for -> Bury
# 9317
# Burial (id: 177497, ns: 0)
# rejected
# 9318
# Burh (id: 3679339, ns: 0)
# rejected
# 9319
# Bury, Cambridgeshire (id: 2793639, ns: 0)
# rejected
# 9320
# Bury, Greater Manchester (id: 300812, ns: 0)
# accepted
# 9321
# Bury (UK Parliament constituency) (id: 7388094, ns: 0)
# rejected
# 9322
# Metropolitan Borough of Bury (id: 635395, ns: 0)
# accepted
# 9323
# County Borough of Bury (id: 18220043, ns: 0)
# accepted
# 9324
# Bury Rural District (id: 3548921, ns: 0)
# accepted
# 9325
# Brompton Regis (id: 3310562, ns: 0)
# accepted
# 9326
# Bury, West Sussex (id: 12786293, ns: 0)
# accepted
# 9327
# Bury (UK electoral ward) (id: 27707000, ns: 0)
# rejected
# 9328
# Bury St Edmunds (id: 208824, ns: 0)
# accepted
# 9329
# Farnworth (id: 753472, ns: 0)
# 9330
# Péruwelz (id: 175360, ns: 0)
# accepted
# 9331
# Bury, Quebec (id: 5831968, ns: 0)
# accepted
# 9332
# ...

# %%
l=z[z.index("Phoenix"):]

with open("final2-2.txt","w+") as f:
    for _ in l:
        f.write(_)
        f.write("\n")

# %%
for _ in l:
    print(">>")
    try:
        content=wikipedia.page(_).content
        try:
            k=content.find("== See also ==")
        except ValueError as e:
            print("solving *")
            try:
                k=content.find("== References ==")
            except:
                try:
                    k=content.find("== Further reading ==")
                except:
                    try:
                        k=content.find("== External links ==")
                    except:
                        pass
                    else:
                        content=content[0:k]
                else:
                    content=content[0:k]
                    
            else:
                content=content[0:k]
                
        else:
            content=content[0:k]
        
            
        if(c==0):
            f=open('%s.txt' % _,'w+')
            f.write(content)
            f.write("\n\n\n\n\n")
            f.write("tags\n")
            string=' '
            tags=re.findall(r'== (.*?) ==',content)
            
            if("References" in tags):
                tags.remove("References")
            if("External links" in tags):
                tags.remove("External links")
            if("See also" in tags):
                tags.remove("See also")
            if("Further reading" in tags):
                tags.remove("Further reading")
            l=string.join(tags)
            f.write(l)
        c=c+1
        a[_]={}
        a[_]["content"]=content
        tags=re.findall(r'== (.*?) ==',content)
        if("References" in tags):
            tags.remove("References")
        if("External links" in tags):
            tags.remove("External links")
        if("See also" in tags):
            tags.remove("See also")
        if("Further reading" in tags):
            tags.remove("Further reading")
        a[_]["headings"]= tags
        print(c)
        
    except Exception as exception:
        print("Inside an exception")
        print(type(exception))
        if(type(exception)==wikipedia.exceptions.DisambiguationError):
            print("Error coming for",end=" -> ")
            print(_)
            for check in exception.options:
                pg=wiki.page(check)
                if(pg.exists()):
                    c=c+1
                    print(c)
                    print(pg)
                    try:    
                        content=wikipedia.page(check).content
                        try:
                            x=content.find(".")
                        except:
                            print("rejected")
                        else:
                            l=content[0:x]
                            if("city" in l or "municipality" in l or "district" in l or "province" in l or "town" in l or "metropolis" in l):
                                print("accepted")
                                a[check]={}
                                try:
                                    k=content.find("== See also ==")
                                except:
                                    try:
                                        k=content.find("== References ==")
                                    except:
                                        try:
                                            k=content.find("== Further reading ==")
                                        except:
                                            try:
                                                k=content.find("== External links ==")
                                            except:
                                                pass
                                            else:
                                                content=content[0:k]
                                        else:
                                            content=content[0:k]
                    
                                    else:
                                        content=content[0:k]
                    
                                else:
                                    content=content[0:k]
                                a[check]["content"]=content
                                tags=re.findall(r'== (.*?) ==',content)
                                if("References" in tags):
                                    tags.remove("References")
                                if("External links" in tags):
                                    tags.remove("External links")
                                if("See also" in tags):
                                    tags.remove("See also")
                                if("Further reading" in tags):
                                    tags.remove("Further reading")
                                a[check]["headings"]=tags
                            else:
                                print("rejected")
                    except:
                        pass
                else:
                    continue
        else:
            pass
# Out:
# >>
# Inside an exception
# <class 'wikipedia.exceptions.DisambiguationError'>
# Error coming for -> Phoenix
# 12454
# Phoenix (mythology) (id: 49122, ns: 0)
# rejected
# 12455
# Phoenix, Arizona (id: 49121, ns: 0)
# accepted
# 12456
# Phoenix (son of Amyntor) (id: 49124, ns: 0)
# rejected
# 12457
# Phoenix of Phoenicia (id: 12777929, ns: 0)
# rejected
# 12458
# Phoenix (Greek myth) (id: 58634155, ns: 0)
# rejected
# 12459
# Bennu (id: 1376318, ns: 0)
# rejected
# 12460
# Garuda (id: 45806, ns: 0)
# rejected
# 12461
# Firebird (Slavic folklore) (id: 1204214, ns: 0)
# rejected
# 12462
# Simurgh (id: 348145, ns: 0)
# rejected
# 12463
# Fenghuang (id: 266654, ns: 0)
# rejected
# 12464
# Vermilion Bird (id: 6090780, ns: 0)
# rejected
# 12465
# Chol (Bible) (id: 40545832, ns: 0)
# rejected
# 12466
# Nine-headed Bird (id: 2463001, ns: 0)
# rejected
# 12467
# Phenex (id: 263724, ns: 0)
# rejected
# 12468
# Huma bird (id: 5123641, ns: 0)
# rejected
# 12469
# ...

# %%
l=z[z.index("Beverly"):]

with open("final2-2.txt","w+") as f:
    for _ in l:
        f.write(_)
        f.write("\n")

# %%
for _ in l:
    print(">>")
    try:
        content=wikipedia.page(_).content
        try:
            k=content.find("== See also ==")
        except ValueError as e:
            print("solving *")
            try:
                k=content.find("== References ==")
            except:
                try:
                    k=content.find("== Further reading ==")
                except:
                    try:
                        k=content.find("== External links ==")
                    except:
                        pass
                    else:
                        content=content[0:k]
                else:
                    content=content[0:k]
                    
            else:
                content=content[0:k]
                
        else:
            content=content[0:k]
        
            
        if(c==0):
            f=open('%s.txt' % _,'w+')
            f.write(content)
            f.write("\n\n\n\n\n")
            f.write("tags\n")
            string=' '
            tags=re.findall(r'== (.*?) ==',content)
            
            if("References" in tags):
                tags.remove("References")
            if("External links" in tags):
                tags.remove("External links")
            if("See also" in tags):
                tags.remove("See also")
            if("Further reading" in tags):
                tags.remove("Further reading")
            l=string.join(tags)
            f.write(l)
        c=c+1
        a[_]={}
        a[_]["content"]=content
        tags=re.findall(r'== (.*?) ==',content)
        if("References" in tags):
            tags.remove("References")
        if("External links" in tags):
            tags.remove("External links")
        if("See also" in tags):
            tags.remove("See also")
        if("Further reading" in tags):
            tags.remove("Further reading")
        a[_]["headings"]= tags
        print(c)
        
    except Exception as exception:
        print("Inside an exception")
        print(type(exception))
        if(type(exception)==wikipedia.exceptions.DisambiguationError):
            print("Error coming for",end=" -> ")
            print(_)
            for check in exception.options:
                pg=wiki.page(check)
                if(pg.exists()):
                    c=c+1
                    print(c)
                    print(pg)
                    try:    
                        content=wikipedia.page(check).content
                        try:
                            x=content.find(".")
                        except:
                            print("rejected")
                        else:
                            l=content[0:x]
                            if("city" in l or "municipality" in l or "district" in l or "province" in l or "town" in l or "metropolis" in l):
                                print("accepted")
                                a[check]={}
                                try:
                                    k=content.find("== See also ==")
                                except:
                                    try:
                                        k=content.find("== References ==")
                                    except:
                                        try:
                                            k=content.find("== Further reading ==")
                                        except:
                                            try:
                                                k=content.find("== External links ==")
                                            except:
                                                pass
                                            else:
                                                content=content[0:k]
                                        else:
                                            content=content[0:k]
                    
                                    else:
                                        content=content[0:k]
                    
                                else:
                                    content=content[0:k]
                                a[check]["content"]=content
                                tags=re.findall(r'== (.*?) ==',content)
                                if("References" in tags):
                                    tags.remove("References")
                                if("External links" in tags):
                                    tags.remove("External links")
                                if("See also" in tags):
                                    tags.remove("See also")
                                if("Further reading" in tags):
                                    tags.remove("Further reading")
                                a[check]["headings"]=tags
                            else:
                                print("rejected")
                    except:
                        pass
                else:
                    continue
        else:
            pass
# Out:
# >>
# Inside an exception
# <class 'wikipedia.exceptions.DisambiguationError'>
# Error coming for -> Beverly
# 15131
# Beverley, South Australia (id: 24011354, ns: 0)
# rejected
# 15132
# Beverley, Western Australia (id: 2626370, ns: 0)
# 15133
# Shire of Beverley (id: 7735685, ns: 0)
# rejected
# 15134
# Beverly, Alberta (id: 10717762, ns: 0)
# accepted
# 15135
# Beverley, Saskatchewan (id: 25137028, ns: 0)
# rejected
# 15136
# Beverley (id: 144454, ns: 0)
# accepted
# 15137
# Beverley (borough) (id: 658932, ns: 0)
# accepted
# 15138
# Beverley railway station (id: 3829762, ns: 0)
# accepted
# 15139
# Beverley Beck (id: 11122073, ns: 0)
# rejected
# 15140
# Beverley Minster (id: 144455, ns: 0)
# rejected
# 15141
# Beverley Racecourse (id: 8822111, ns: 0)
# accepted
# 15142
# Beverley Rural District (id: 18441873, ns: 0)
# accepted
# 15143
# Beverley (UK Parliament constituency) (id: 6367249, ns: 0)
# rejected
# 15144
# Beverley Brook (id: 1413066, ns: 0)
# rejected
# 15145
# ...

# %%
l=z[z.index("Kadoma"):]

with open("final2-2.txt","w+") as f:
    for _ in l:
        f.write(_)
        f.write("\n")

# %%
for _ in l:
    print(">>")
    try:
        content=wikipedia.page(_).content
        try:
            k=content.find("== See also ==")
        except ValueError as e:
            print("solving *")
            try:
                k=content.find("== References ==")
            except:
                try:
                    k=content.find("== Further reading ==")
                except:
                    try:
                        k=content.find("== External links ==")
                    except:
                        pass
                    else:
                        content=content[0:k]
                else:
                    content=content[0:k]
                    
            else:
                content=content[0:k]
                
        else:
            content=content[0:k]
        
            
        if(c==0):
            f=open('%s.txt' % _,'w+')
            f.write(content)
            f.write("\n\n\n\n\n")
            f.write("tags\n")
            string=' '
            tags=re.findall(r'== (.*?) ==',content)
            
            if("References" in tags):
                tags.remove("References")
            if("External links" in tags):
                tags.remove("External links")
            if("See also" in tags):
                tags.remove("See also")
            if("Further reading" in tags):
                tags.remove("Further reading")
            l=string.join(tags)
            f.write(l)
        c=c+1
        a[_]={}
        a[_]["content"]=content
        tags=re.findall(r'== (.*?) ==',content)
        if("References" in tags):
            tags.remove("References")
        if("External links" in tags):
            tags.remove("External links")
        if("See also" in tags):
            tags.remove("See also")
        if("Further reading" in tags):
            tags.remove("Further reading")
        a[_]["headings"]= tags
        print(c)
        
    except Exception as exception:
        print("Inside an exception")
        print(type(exception))
        if(type(exception)==wikipedia.exceptions.DisambiguationError):
            print("Error coming for",end=" -> ")
            print(_)
            for check in exception.options:
                pg=wiki.page(check)
                if(pg.exists()):
                    c=c+1
                    print(c)
                    print(pg)
                    try:    
                        content=wikipedia.page(check).content
                        try:
                            x=content.find(".")
                        except:
                            print("rejected")
                        else:
                            l=content[0:x]
                            if("city" in l or "municipality" in l or "district" in l or "province" in l or "town" in l or "metropolis" in l):
                                print("accepted")
                                a[check]={}
                                try:
                                    k=content.find("== See also ==")
                                except:
                                    try:
                                        k=content.find("== References ==")
                                    except:
                                        try:
                                            k=content.find("== Further reading ==")
                                        except:
                                            try:
                                                k=content.find("== External links ==")
                                            except:
                                                pass
                                            else:
                                                content=content[0:k]
                                        else:
                                            content=content[0:k]
                    
                                    else:
                                        content=content[0:k]
                    
                                else:
                                    content=content[0:k]
                                a[check]["content"]=content
                                tags=re.findall(r'== (.*?) ==',content)
                                if("References" in tags):
                                    tags.remove("References")
                                if("External links" in tags):
                                    tags.remove("External links")
                                if("See also" in tags):
                                    tags.remove("See also")
                                if("Further reading" in tags):
                                    tags.remove("Further reading")
                                a[check]["headings"]=tags
                            else:
                                print("rejected")
                    except:
                        pass
                else:
                    continue
        else:
            pass
# Out:
# >>
# Inside an exception
# <class 'wikipedia.exceptions.DisambiguationError'>
# Error coming for -> Kadoma
# 15671
# Kadoma, Osaka (id: 329223, ns: 0)
# accepted
# 15672
# Kadoma, Zimbabwe (id: 7113607, ns: 0)
# accepted
# 15673
# Kadoma District (id: 17652316, ns: 0)
# accepted
# >>
# 15674
# >>
# 15675
# >>
# 15676
# >>
# 15677
# >>
# 15678
# >>
# 15679
# >>
# 15680
# >>
# 15681
# >>
# 15682
# >>
# 15683
# >>
# 15684
# >>
# 15685
# >>
# Inside an exception
# <class 'wikipedia.exceptions.DisambiguationError'>
# Error coming for -> Hyde Park
# 15686
# Hyde Park, London (id: 211289, ns: 0)
# rejected
# 15687
# Hyde Park, Leeds (id: 925867, ns: 0)
# accepted
# 15688
# Hyde Park, Sheffield (id: 3785701, ns: 0)
# accepted
# 15689
# Hyde, Greater Manchester (id: 513981, ns: 0)
# accepted
# 15690
# Doncaster (id: 154276, ns: 0)
# accepted
# 15691
# Hyde Park, New York (id: 126377, ns: 0)
# accepted
# 15692
# Hyde Park (CDP), New York (id: 37507152, ns: 0)
# accepted
# 15693
# ...

# %%
l=z[z.index("Dharmavaram"):]

with open("final2-2.txt","w+") as f:
    for _ in l:
        f.write(_)
        f.write("\n")

# %%
for _ in l:
    print(">>")
    try:
        content=wikipedia.page(_).content
        try:
            k=content.find("== See also ==")
        except ValueError as e:
            print("solving *")
            try:
                k=content.find("== References ==")
            except:
                try:
                    k=content.find("== Further reading ==")
                except:
                    try:
                        k=content.find("== External links ==")
                    except:
                        pass
                    else:
                        content=content[0:k]
                else:
                    content=content[0:k]
                    
            else:
                content=content[0:k]
                
        else:
            content=content[0:k]
        
            
        if(c==0):
            f=open('%s.txt' % _,'w+')
            f.write(content)
            f.write("\n\n\n\n\n")
            f.write("tags\n")
            string=' '
            tags=re.findall(r'== (.*?) ==',content)
            
            if("References" in tags):
                tags.remove("References")
            if("External links" in tags):
                tags.remove("External links")
            if("See also" in tags):
                tags.remove("See also")
            if("Further reading" in tags):
                tags.remove("Further reading")
            l=string.join(tags)
            f.write(l)
        c=c+1
        a[_]={}
        a[_]["content"]=content
        tags=re.findall(r'== (.*?) ==',content)
        if("References" in tags):
            tags.remove("References")
        if("External links" in tags):
            tags.remove("External links")
        if("See also" in tags):
            tags.remove("See also")
        if("Further reading" in tags):
            tags.remove("Further reading")
        a[_]["headings"]= tags
        print(c)
        
    except Exception as exception:
        print("Inside an exception")
        print(type(exception))
        if(type(exception)==wikipedia.exceptions.DisambiguationError):
            print("Error coming for",end=" -> ")
            print(_)
            for check in exception.options:
                pg=wiki.page(check)
                if(pg.exists()):
                    c=c+1
                    print(c)
                    print(pg)
                    try:    
                        content=wikipedia.page(check).content
                        try:
                            x=content.find(".")
                        except:
                            print("rejected")
                        else:
                            l=content[0:x]
                            if("city" in l or "municipality" in l or "district" in l or "province" in l or "town" in l or "metropolis" in l):
                                print("accepted")
                                a[check]={}
                                try:
                                    k=content.find("== See also ==")
                                except:
                                    try:
                                        k=content.find("== References ==")
                                    except:
                                        try:
                                            k=content.find("== Further reading ==")
                                        except:
                                            try:
                                                k=content.find("== External links ==")
                                            except:
                                                pass
                                            else:
                                                content=content[0:k]
                                        else:
                                            content=content[0:k]
                    
                                    else:
                                        content=content[0:k]
                    
                                else:
                                    content=content[0:k]
                                a[check]["content"]=content
                                tags=re.findall(r'== (.*?) ==',content)
                                if("References" in tags):
                                    tags.remove("References")
                                if("External links" in tags):
                                    tags.remove("External links")
                                if("See also" in tags):
                                    tags.remove("See also")
                                if("Further reading" in tags):
                                    tags.remove("Further reading")
                                a[check]["headings"]=tags
                            else:
                                print("rejected")
                    except:
                        pass
                else:
                    continue
        else:
            pass
# Out:
# >>
# Inside an exception
# <class 'wikipedia.exceptions.DisambiguationError'>
# Error coming for -> Dharmavaram
# 22930
# Dharmavaram, Anantapur district (id: 2238253, ns: 0)
# accepted
# 22931
# Dharmavaram revenue division (id: 49849804, ns: 0)
# accepted
# 22932
# Dharmavaram, Vizianagaram district (id: 11708006, ns: 0)
# accepted
# 22933
# Dharmavaram, West Godavari district (id: 13710239, ns: 0)
# accepted
# 22934
# Dharmavaram, Guntur district (id: 56154258, ns: 0)
# accepted
# 22935
# Dharmavaram Junction railway station (id: 46207039, ns: 0)
# accepted
# >>
# 22936
# >>
# 22937
# >>
# Inside an exception
# <class 'wikipedia.exceptions.DisambiguationError'>
# Error coming for -> Bluffton
# 22938
# Bluffton, Alberta (id: 24368456, ns: 0)
# rejected
# 22939
# Bluffton, Alabama (id: 42979529, ns: 0)
# rejected
# 22940
# Bluffton, Arkansas (id: 31709071, ns: 0)
# rejected
# 22941
# Bluffton, Georgia (id: 109966, ns: 0)
# accepted
# 22942
# Bluffton, Indiana (id: 112693, ns: 0)
# ...
