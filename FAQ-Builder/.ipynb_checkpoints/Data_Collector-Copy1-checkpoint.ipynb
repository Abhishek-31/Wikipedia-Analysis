# %%
import re
import wikipedia
import wikipediaapi

# %%
with open("final2.txt","r") as f:
    z=f.read().split('\n')
myset=set(z)
z=list(myset)

z.remove('')
print(z)
with open("final2.txt","w+") as f:
    for _ in z:
        f.write(_)
        f.write("\n")
# Out:
# ['Aurora', 'Iracemápolis', 'Irbid', 'Leesburg', 'Kutná Hora', 'Livingstone', 'Kazo', 'Zhytomyr', 'Tangerang Selatan', 'Dublin', 'Lingen', 'East Hartford', 'Katsuragi', 'Groningen', 'Richfield', 'Lodi', 'New Haven', 'Dachau', 'Uberlândia', 'Tarapoto', 'Motosu', 'Korschenbroich', 'Nanjing', 'Missoula', 'Catbalogan', 'Yao', 'Salamanca', 'Kōnosu', 'Mae Cho', 'Calapan', 'Boujad', 'Wernigerode', 'Schramberg', 'Lake Forest', 'Suzhou', 'Wiehl', 'Searcy', 'Janakpurdham', 'Porto', 'Tornio', 'Tokat', 'Bareq', 'Lake Charles', 'Mima', 'Herndon', 'Gimpo', 'Sønderborg', 'Aschersleben', 'Biên Hòa', 'Portmore', 'Tômbwa', 'Dodge City', 'South Salt Lake', 'North Kingstown', 'Fountain Hills', 'Satte', 'Amritsar', 'Santos', 'Crystal', 'Perrysburg', 'La Porte', 'Morgantown', 'Toki', 'Tewksbury', 'Loei', 'Bardaskan', 'Oak Creek', 'Loja', 'Rio Maior Municipality', 'Kadapa', 'Milwaukie', 'Canelones', 'Hachiōji', 'Queensbury', 'Lichtenfels', 'Atbarah', 'Khovd', 'Cavite City', 'Chōshi', 'Câmara de Lobos', 'Ulanqab', 'Warren', 'Rio Rancho', 'Salisbury', 'Ponte de Lima', 'Jerez de la Frontera', 'South Portland', 'Redlands', 'Yuxi', 'Embu das Artes', 'Tacoma', 'Grand Rapids', 'Levice', 'Ulcinj', 'Tansen', 'Chengde', 'Ferreñafe', 'Hasköy', 'Yaita', 'Khlong Luang', 'Adapazarı', 'Apache Junction', 'Glen Cove', 'Lashkar Gah', 'Ainan', 'Samut Songkhram', 'Thetford Mines', 'San Andrés', 'Guyuan', 'Christiansburg', 'Seiyun', 'Tiberias', 'Martos', 'Dushanbe', 'Chamdo', 'Guayaramerín', 'Brooklyn Park', 'Cottonwood Heights', 'Buri Ram', 'Ishikari', 'Indian Trail', 'West Lafayette', 'Pokhara', 'Mingora', 'Omaezaki', 'Dudley', 'Bowie', 'Cubatão', 'Hilo', 'Burbank', 'Lille', 'Iida', 'Comrat', 'Arnhem', 'Ichihara', 'Azna, Lorestan', 'Akron', 'Barahona', 'Brossard', 'Vila do Conde', 'Edmond', 'Tynemouth', 'Suwa', 'Selouane', 'Bursa', 'Piura', 'Oberkirch', 'Taquaritinga', 'Billerica', 'Bell Gardens', 'Sint-Truiden', 'Damietta', 'Budapest', 'New Cairo', 'Nanterre', 'Behbahan', 'Lutsk', 'Oberhausen', 'Cáceres', 'Kōfu', 'Velenje', 'Burnaby', 'Lakeville', 'Novorossiysk', 'Cúcuta', 'Korosten', 'Malout', 'Izeh', 'Aïn El Aouda', 'Kiryat Malakhi', 'Bimbo', 'Maracay', 'Navoiy', 'Zama', 'Rohnert Park', 'Usa', 'Easton', 'Naas', 'Bandarlampung', 'Higashiyamato', 'Managua', 'Weihai', 'Artvin', 'Lawrence', 'Dunakeszi', 'Vratsa', 'Kirkcaldy', 'McMinnville', 'Xining', 'Telford', 'Katagami', 'Velingrad', 'Ecatepec de Morelos', 'Raymore', 'Hackensack', 'Taounate', 'Jackson', 'Kashiba', 'Kamakura', 'Ghaziabad', 'São Carlos', 'Morristown', 'Konye-Urgench', 'La Troncal', 'Liupanshui', 'Peterborough', 'Ho', 'Miura', 'Helwan', 'Vizianagaram', 'Rosemount', 'Sarıkaya', 'Alloa', 'Spring Hill', 'Ubon Ratchathani', 'Santa Rosa de Viterbo', 'Sofia', 'Zolochiv', 'Pemangkat', 'Akitakata', 'Brownwood', 'Ibb', 'DeWitt', 'Schwerte', 'Trois-Rivières', 'Higashimurayama', 'Chaiyaphum', 'Lublin', 'Ronse', 'Mocuba', 'Wellington City', 'Port Moresby', 'Silay', 'Moroni', 'Comandante Andresito', 'Chirmiri', 'Santa Fe', 'Tibati', 'Bethlehem', 'Jiuquan', 'Dura, Hebron', 'Farragut', 'Norfolk', 'Coatzacoalcos', 'Baoding', 'Ebebiyín', 'Bacău', 'Southport', 'Lusaka', 'Memmingen', 'Nishitōkyō', 'Na San', 'Rittō', 'Algiers', 'Kathu', 'Brodowski, São Paulo', 'Chapel Hill', 'Kafr el-Dawwar', 'San Miguel', 'Neustadt an der Weinstraße', 'West Seneca', 'Saint-Lazare', 'Uonuma', 'Imabari', 'Phoenix', 'Worms', 'Osan', 'Kermanshah', 'Glendale', 'Augusta', 'Newburgh (town), New York', 'Kanmaki', 'Junqueirópolis', 'Siguatepeque', 'Suzaka', 'Mason', 'Gahanna', 'Mansoura', 'Suining', 'Qitaihe', 'Pharr', 'Oskemen', 'Oregon', 'Vilnohirsk', 'Hegang', 'Kent', 'Milton', 'Elmhurst', 'Devarakonda', 'Pisa', 'Stanton', 'Niamey', 'Rees', 'Naumburg (Saale)', 'Pak Chong', 'Xonobod', 'Gotemba', 'Yehud', 'Bergen', 'Helsinki', 'Vinhedo', 'Myrtle Beach', 'Onondaga', 'Sorokyne', 'Chongju', 'Tsuchiura', 'Long Xuyên', 'Itapevi', 'Altamonte Springs', 'Iga', 'Embu', 'Bulle', 'Eugene', 'Leeds', 'Koszalin', 'Lynn', 'Mission', 'Battambang', 'Baybay', 'Ikar ...

# %%
a={}
c=0
print("Files done")
wiki = wikipediaapi.Wikipedia('en')
for _ in z:
    print(">>")
    try:
        content=wikipedia.page(_).content
        try:
            k=content.find("== See also ==")
        except ValueError as e:
            print("solving *")
            try:
                k=content.find("== References ==")
            except:
                try:
                    k=content.find("== Further reading ==")
                except:
                    try:
                        k=content.find("== External links ==")
                    except:
                        pass
                    else:
                        content=content[0:k]
                else:
                    content=content[0:k]
                    
            else:
                content=content[0:k]
                
        else:
            content=content[0:k]
        
            
        if(c==0):
            f=open('%s.txt' % _,'w+')
            f.write(content)
            f.write("\n\n\n\n\n")
            f.write("tags\n")
            string=' '
            tags=re.findall(r'== (.*?) ==',content)
            
            if("References" in tags):
                tags.remove("References")
            if("External links" in tags):
                tags.remove("External links")
            if("See also" in tags):
                tags.remove("See also")
            if("Further reading" in tags):
                tags.remove("Further reading")
            l=string.join(tags)
            f.write(l)
        c=c+1
        a[_]={}
        a[_]["content"]=content
        tags=re.findall(r'== (.*?) ==',content)
        if("References" in tags):
            tags.remove("References")
        if("External links" in tags):
            tags.remove("External links")
        if("See also" in tags):
            tags.remove("See also")
        if("Further reading" in tags):
            tags.remove("Further reading")
        a[_]["headings"]= tags
        print(c)
        
    except Exception as exception:
        print("Inside an exception")
        print(type(exception))
        if(type(exception)==wikipedia.exceptions.DisambiguationError):
            print(_)
            for check in exception.options:
                pg=wiki.page(check)
                if(pg.exists()):
                    c=c+1
                    print(c)
                    print(pg)
                    try:    
                        content=wikipedia.page(check).content
                        try:
                            x=content.find(".")
                        except:
                            print("rejected")
                        else:
                            l=content[0:x]
                            if("city" in l or "municipality" in l or "district" in l or "province" in l or "town" in l or "metropolis" in l):
                                print("accepted")
                                a[check]={}
                                try:
                                    k=content.find("== See also ==")
                                except:
                                    try:
                                        k=content.find("== References ==")
                                    except:
                                        try:
                                            k=content.find("== Further reading ==")
                                        except:
                                            try:
                                                k=content.find("== External links ==")
                                            except:
                                                pass
                                            else:
                                                content=content[0:k]
                                        else:
                                            content=content[0:k]
                    
                                    else:
                                        content=content[0:k]
                    
                                else:
                                    content=content[0:k]
                                a[check]["content"]=content
                                tags=re.findall(r'== (.*?) ==',content)
                                if("References" in tags):
                                    tags.remove("References")
                                if("External links" in tags):
                                    tags.remove("External links")
                                if("See also" in tags):
                                    tags.remove("See also")
                                if("Further reading" in tags):
                                    tags.remove("Further reading")
                                a[check]["headings"]=tags
                            else:
                                print("rejected")
                    except:
                        pass
                else:
                    continue
        else:
            pass
